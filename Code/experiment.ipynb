# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# %%
# Load datasets
train_orig = pd.read_csv("train_original.csv")

test_random = pd.read_csv("test_random.csv")
test_random_scaled = pd.read_csv("test_random_scaled.csv")

test_near = pd.read_csv("test_near.csv")
test_near_scaled = pd.read_csv("test_near_scaled.csv")

# %%
# Train model on original data
rf_orig = RandomForestClassifier(random_state=42, n_estimators=100)
rf_orig.fit(train_orig[["X1", "X2"]], train_orig["y"])
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Evaluate original model
acc_orig_random = accuracy_score(test_random["y"], rf_orig.predict(test_random[["X1", "X2"]]))
acc_orig_near   = accuracy_score(test_near["y"], rf_orig.predict(test_near[["X1", "X2"]]))

# Evaluate scaled model
acc_scaled_random = accuracy_score(test_random_scaled["y"], rf_orig.predict(test_random_scaled[["X1", "X2"]]))
acc_scaled_near   = accuracy_score(test_near_scaled["y"], rf_orig.predict(test_near_scaled[["X1", "X2"]]))

# %%
# Print results
print(f"Train = original | Test = random          → Accuracy: {acc_orig_random:.3f}")
print(f"Train = original | Test = near-split      → Accuracy: {acc_orig_near:.3f}")
print(f"Train = original | Test = random_scaled   → Accuracy: {acc_scaled_random:.3f}")
print(f"Train = original | Test = near_scaled     → Accuracy: {acc_scaled_near:.3f}")
# Out:
# Train = original | Test = random          → Accuracy: 0.970
# Train = original | Test = near-split      → Accuracy: 0.440
# Train = original | Test = random_scaled   → Accuracy: 0.820
# Train = original | Test = near_scaled     → Accuracy: 0.440

# %%
train_orig.head(10)
# Out:
#          X1        X2  y
# 0  3.745401  9.507143  1
# 1  7.319939  5.986585  1
# 2  1.560186  1.559945  0
# 3  0.580836  8.661761  0
# 4  6.011150  7.080726  1
# 5  0.205845  9.699099  0
# 6  8.324426  2.123391  1
# 7  1.818250  1.834045  0
# 8  3.042422  5.247564  0
# 9  4.319450  2.912291  0

# %%
test_random.head(10)
# Out:
#          X1        X2  y
# 0  1.689351  2.785903  0
# 1  1.770105  0.887025  0
# 2  1.206359  4.607788  0
# 3  2.063337  3.642699  0
# 4  5.034173  6.903948  1
# 5  0.393121  7.994104  0
# 6  6.279004  0.817590  0
# 7  8.735786  9.208724  1
# 8  0.610780  2.768776  0
# 9  8.062013  7.482597  1

# %%
test_random_scaled.head(10)
# Out:
#           X1        X2  y
# 0   3.378701  1.392952  0
# 1   3.540210  0.443513  0
# 2   2.412717  2.303894  0
# 3   4.126674  1.821349  0
# 4  10.068345  3.451974  1
# 5   0.786243  3.997052  0
# 6  12.558008  0.408795  0
# 7  17.471572  4.604362  1
# 8   1.221559  1.384388  0
# 9  16.124026  3.741298  1

# %%
test_near.head(10)
# Out:
#          X1        X2  y
# 0  5.041448  4.930508  0
# 1  5.015258  5.021343  1
# 2  4.984826  5.047289  1
# 3  5.086873  5.085114  1
# 4  4.990168  4.922648  0
# 5  5.096968  5.067780  1
# 6  4.924933  5.084168  1
# 7  5.073979  5.003768  1
# 8  5.018255  4.979801  0
# 9  4.910952  4.967039  0

# %%
test_near_scaled.head(10)
# Out:
#           X1        X2  y
# 0  10.082895  2.465254  0
# 1  10.030515  2.510672  1
# 2   9.969652  2.523644  1
# 3  10.173747  2.542557  1
# 4   9.980336  2.461324  0
# 5  10.193936  2.533890  1
# 6   9.849865  2.542084  1
# 7  10.147959  2.501884  1
# 8  10.036510  2.489900  0
# 9   9.821905  2.483520  0
